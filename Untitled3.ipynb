# %%
from datetime import timedelta, date

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(30*n)
    
import requests
import json
PUBLIC = '9NMNENSPz413EK0z0vrnqId2v4A3iYbX'
requestHeaders = {
"Accept": "application/json"
}
request = []
print(out)
heads = [(i['headline']['main'],i['pub_date'][:7]) for i in out]
len(heads)
start_date = date(1898, 1, 1)
end_date = date(1929, 1, 1)
dates = daterange(start_date, end_date)
for i in range(len(dates)-1):
    date = single_date.strftime("%Y%m%d")
    requestUrl = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?begin_date={date}&end_date={date}&facet=true&facet_filter=false&q=DEBS&sort=oldest&api-key={PUBLIC}"
    request.append(json.loads(requests.get(requestUrl, headers=requestHeaders).content))
print(request)
# Out:
# [{'abstract': 'The terms of the proposed absorption of the West Shore Road by the New-York Central were officially announced in Wall-street yesterday by the distribution of a circular signed by Drexel, Morgan  Co. and addressed to the first mortgage bondholders of the road which is to be absorbed. Messrs. Drexel, Morgan  Co. explain that, having been convinced that the interests of the New-York Central and...', 'web_url': 'https://www.nytimes.com/1885/07/28/archives/in-the-railway-world-terms-of-the-proposed-west-shore-absorption.html', 'snippet': '', 'lead_paragraph': '', 'print_page': '2', 'source': 'The New York Times', 'multimedia': [], 'headline': {'main': 'IN THE RAILWAY WORLD; TERMS OF THE PROPOSED WEST SHORE ABSORPTION. THE BONDHOLDERS OFFERED FIFTY PER CENT. AND THE STOCK TO BE WIPED OUT--THE BEST THEY CAN DO.', 'kicker': None, 'content_kicker': None, 'print_headline': 'IN THE RAILWAY WORLD; TERMS OF THE PROPOSED WEST SHORE ABSORPTION. THE BONDHOLDERS OFFERED FIFTY PER CENT.
# ...

# %%
request
# Out:
# [{'status': 'OK',
#   'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights Reserved.',
#   'response': {'docs': [],
#    'meta': {'hits': 0, 'offset': 0, 'time': 156},
#    'facets': {}}},
#  {'status': 'OK',
#   'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights Reserved.',
#   'response': {'docs': [],
#    'meta': {'hits': 0, 'offset': 0, 'time': 38},
#    'facets': {}}},
#  {'status': 'OK',
#   'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights Reserved.',
#   'response': {'docs': [],
#    'meta': {'hits': 0, 'offset': 0, 'time': 9},
#    'facets': {}}},
#  {'status': 'OK',
#   'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights Reserved.',
#   'response': {'docs': [],
#    'meta': {'hits': 0, 'offset': 0, 'time': 13},
#    'facets': {}}},
#  {'status': 'OK',
#   'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights Reserved.',
# ...
